# %% [markdown]
# ## 방탈출 사이트 예약 확인하고 알림 보내기
# - selenium reference
#     - https://sulmasulma.github.io/etc/2020/07/22/empty-seat.html
#     - https://heodolf.tistory.com/80
# - kakaotalk reference: https://liwonfather.tistory.com/2
# - 오류 수정 reference
#     - click error: https://yourtime.kr/entry/%EC%85%80%EB%A0%88%EB%8B%88%EC%9B%80-%EB%B2%84%ED%8A%BC-%ED%81%B4%EB%A6%AD-%EC%97%90%EB%9F%AC-%EB%B0%9C%EC%83%9D-%EC%8B%9C-%ED%95%B4%EA%B2%B0%EB%B0%A9%EB%B2%95
#     - StaleElementReferenceException: https://velog.io/@jcinsh/%ED%81%AC%EB%A1%A4%EB%A7%81-%EC%8B%9C-%EB%AC%B8%EC%A0%9C-%ED%95%B4%EA%B2%B0
# - 샤이썬(서울대 수강신청 빈자리 알리미) 같은 기능을 만들고자 함

# %%
import requests
import json

url = 'https://kauth.kakao.com/oauth/token'
client_id = ''
redirect_uri = ''
code = ''
data = {
    'grant_type':'authorization_code',
    'client_id':client_id,
    'redirect_uri':redirect_uri,
    'code': code,
    }

response = requests.post(url, data=data)
tokens = response.json()

#발행된 토큰 저장
with open("token.json","w") as kakao:
    json.dump(tokens, kakao)

# %%
def send_kakao_text(room_text):
        with open("token.json","r") as kakao:
            tokens = json.load(kakao)

        url="https://kapi.kakao.com/v2/api/talk/memo/default/send"

        headers={
            "Authorization" : "Bearer " + tokens["access_token"]
        }

        data = {
               'object_type': 'text',
               'text': room_text,
               'link': {
                   'web_url': 'https://developers.kakao.com',
                   'mobile_web_url': 'https://developers.kakao.com'
               },
           }

        data = {'template_object': json.dumps(data)}
        response = requests.post(url, headers=headers, data=data)
        response.status_code

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time

driver = webdriver.Chrome('chromedriver.exe')
url = 'https://keyescape.co.kr/web/home.php?go=rev.make'
driver.get(url)
time.sleep(3)
repeat = 0

while True:
    for spot in driver.find_elements_by_css_selector('div div > div > div > div > dl > dd > div > ul > a')[:2]: # 우주라이크, 더오름
        repeat += 1
        # 하나씩 클릭
        spot_text = spot.text
        spot.send_keys(Keys.ENTER)
        time.sleep(3)
        # 날짜 클릭
        for dat1 in driver.find_elements_by_css_selector('div div > div > div > div > dl#rev2.rev2 table.t_calendar td.day_index > a'):
            date_text = dat1.text
            dat1.send_keys(Keys.ENTER)
            time.sleep(3)
            # 테마 클릭
            for theme in driver.find_elements_by_css_selector('div div > div > div > div > dl.rev3 ul#theme_data.revlist > a'):
                theme_text = theme.text
                theme.send_keys(Keys.ENTER)
                time.sleep(3)
                # 시간 비는지 확인
                for postime in driver.find_elements_by_css_selector('div div > div > div > div > dl.rev4 ul#theme_time_data.revlist > a'):
                    time_text = postime.text
                    room_data = "위치:"+spot_text+" / 날짜:"+date_text+" / 테마:"+theme_text+' / 시간:'+time_text
                    send_kakao_text(room_data)
            
            
        ## 다음 월로 이동
        if repeat%2 == 1:
            next_button = driver.find_element_by_css_selector('div div > div > div > div > dl#rev2.rev2 div.calendar_yymm > li.next > a')
            next_button.send_keys(Keys.ENTER)
            time.sleep(3)
            # 날짜 클릭
            for dat1 in driver.find_elements_by_css_selector('div div > div > div > div > dl#rev2.rev2 table.t_calendar td.day_index > a'):
                date_text = dat1.text
                dat1.send_keys(Keys.ENTER)
                time.sleep(3)
                # 테마 클릭
                for theme in driver.find_elements_by_css_selector('div div > div > div > div > dl.rev3 ul#theme_data.revlist > a'):
                    theme_text = theme.text
                    theme.send_keys(Keys.ENTER)
                    time.sleep(3)
                    # 시간 비는지 확인
                    for postime in driver.find_elements_by_css_selector('div div > div > div > div > dl.rev4 ul#theme_time_data.revlist > a'):
                        time_text = postime.text
                        room_data = "위치:"+spot_text+" / 날짜:"+date_text+" / 테마:"+theme_text+' / 시간:'+time_text
                        send_kakao_text(room_data)
                    
        ## 이전 월로 이동
        else:
            prev_button = driver.find_element_by_css_selector('div div > div > div > div > dl#rev2.rev2 div.calendar_yymm > li.prev > a')
            prev_button.send_keys(Keys.ENTER)
            time.sleep(3)
            # 날짜 클릭
            for dat1 in driver.find_elements_by_css_selector('div div > div > div > div > dl#rev2.rev2 table.t_calendar td.day_index > a'):
                date_text = dat1.text
                dat1.send_keys(Keys.ENTER)
                time.sleep(3)
                # 테마 클릭
                for theme in driver.find_elements_by_css_selector('div div > div > div > div > dl.rev3 ul#theme_data.revlist > a'):
                    theme_text = theme.text
                    theme.send_keys(Keys.ENTER)
                    time.sleep(3)
                    # 시간 비는지 확인
                    for postime in driver.find_elements_by_css_selector('div div > div > div > div > dl.rev4 ul#theme_time_data.revlist > a'):
                        time_text = postime.text
                        room_data = "위치:"+spot_text+" / 날짜:"+date_text+" / 테마:"+theme_text+' / 시간:'+time_text
                        send_kakao_text(room_data)
    
    # 10초마다 새로고침 반복
    time.sleep(10)
    driver.refresh()
